# %% [markdown]
# # Model 구체적 예시 비교

# %% [markdown]
# ## Vision Transformer

# %%
import cv2
from tensorflow import keras
from keras.models import load_model
from tensorflow.keras.models import load_model
import numpy as np
from joblib import load
import tensorflow as tf
from vit_keras import vit, layers
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import img_to_array

# 모델 예측 성능 체크 완료!!!!!! 잘 예측됨 !!!!!!!!
# 우선 먼저, 이미지 예측 되나 확인부터 해보자. 하나의 이미지 가져와서.
vit_model = keras.models.load_model('../vit_model.h5')
# Out:
# c:\Users\USER\anaconda3\envs\pytorch\lib\site-packages\tensorflow_addons\utils\tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(

# %%
class_mapping = {0: 'Bicycle',
 1: 'Bridge',
 2: 'Bus',
 3: 'Car',
 #4: 'Chimney',
 #5: 'Crosswalk',
 6: 'Hydrant',
 #7: 'Motorcycle',
 #8: 'Other',
 #9: 'Palm',
 #10: 'Stair',
 11: 'Traffic Light'}

# %% [markdown]
# ### 3x3 : Big image Test

# %%
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications import imagenet_utils
import numpy as np
import matplotlib.pyplot as plt

# 이미지 경로
img_path = '..\Data\Big Image Data\Hydrant\Hydrant (100).png'

# 이미지 불러오기 및 전처리
img = image.load_img(img_path, target_size=(224, 224))  # 이미지를 불러와서 모델의 입력 사이즈에 맞게 조절합니다.
img_array = image.img_to_array(img)
img_array = np.expand_dims(img_array, axis=0)
img_array = imagenet_utils.preprocess_input(img_array, mode='torch')  # 전처리 (예: normalization)

# 모델을 통한 예측 수행
predictions = vit_model.predict(img_array)
predicted_class = np.argmax(predictions, axis=1)

# 예측 결과 출력
print("Predicted class:", class_mapping[predicted_class[0]])

# 이미지 시각화
plt.imshow(img)
plt.title(f'Predicted: {class_mapping[predicted_class[0]]}')
plt.axis('off')
plt.show()
# Out:
# 1/1 [==============================] - 0s 287ms/step
# Predicted class: Hydrant

# %% [markdown]
# ### 3x3 : small image

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.models import load_model
import matplotlib.patches as patches


def visualize_predictions(image_folder, class_label):
    fig, axs = plt.subplots(3, 3, figsize=(6, 6))

    for i in range(3):
        for j in range(3):
            img_path = os.path.join(image_folder, f'{class_mapping[class_label]}_100_({i}, {j}).jpg')
            
            img = Image.open(img_path)
            new_image = img.resize((224, 224))
            new_image = img_to_array(new_image)
            new_image = new_image / 255.0
            new_image = np.expand_dims(new_image, axis=0)

            predictions = vit_model.predict(new_image)
            predicted_class = np.argmax(predictions, axis=1)[0]

            axs[i, j].imshow(img, zorder=1)
            if predicted_class == class_label:
                title = f"O : {class_mapping[class_label]}"
            else:
                title = f"X : Not {class_mapping[class_label]}"

            axs[i, j].set_title(title)
            axs[i, j].axis('off')

    plt.tight_layout()
    plt.show()

# 함수 호출 예시
visualize_predictions('..\Data\Small Image Data\Hydrant', 6)
# Out:
# 1/1 [==============================] - 6s 6s/step
# 1/1 [==============================] - 0s 312ms/step
# 1/1 [==============================] - 0s 268ms/step
# 1/1 [==============================] - 0s 326ms/step
# 1/1 [==============================] - 0s 305ms/step
# 1/1 [==============================] - 0s 323ms/step
# 1/1 [==============================] - 0s 286ms/step
# 1/1 [==============================] - 0s 232ms/step
# 1/1 [==============================] - 0s 278ms/step

# %% [markdown]
# ### 4x4 small image

# %%
def visualize_grid_predictions(image_path, class_label, grid_size=4):
    # 이미지 불러오기
    original_img = Image.open(image_path)

    # 그리드 크기 설정
    grid_width = original_img.width // grid_size
    grid_height = original_img.height // grid_size

    fig, axs = plt.subplots(grid_size, grid_size, figsize=(8, 8))

    for i in range(grid_size):
        for j in range(grid_size):
            # 그리드 영역으로 이미지 자르기
            left = j * grid_width
            upper = i * grid_height
            right = left + grid_width
            lower = upper + grid_height
            cropped_img = original_img.crop((left, upper, right, lower))
            cropped_img = cropped_img.convert("RGB")

            # 이미지 전처리 및 예측
            new_image = cropped_img.resize((224, 224))
            new_image = img_to_array(new_image)
            new_image = new_image / 255.0
            new_image = np.expand_dims(new_image, axis=0)

            predictions = vit_model.predict(new_image)
            predicted_class = np.argmax(predictions, axis=1)[0]

            # 예측 결과 확인 및 출력
            if predicted_class == class_label:
                title = f"O : {class_mapping[class_label]}"
            else:
                title = f"X : Not {class_mapping[class_label]}"

            axs[i, j].imshow(cropped_img)
            axs[i, j].set_title(title)
            axs[i, j].axis('off')

    plt.tight_layout()
    plt.show()

# 함수 호출 예시
image_path = '..\Data\Big Image Data\Hydrant\Hydrant (100).png'
class_label = 6  # 'Hydrant'에 해당하는 클래스 레이블
visualize_grid_predictions(image_path, class_label)
# Out:
# 1/1 [==============================] - 1s 779ms/step
# 1/1 [==============================] - 1s 761ms/step
# 1/1 [==============================] - 1s 663ms/step
# 1/1 [==============================] - 1s 781ms/step
# 1/1 [==============================] - 1s 636ms/step
# 1/1 [==============================] - 1s 849ms/step
# 1/1 [==============================] - 1s 795ms/step
# 1/1 [==============================] - 1s 768ms/step
# 1/1 [==============================] - 1s 591ms/step
# 1/1 [==============================] - 1s 825ms/step
# 1/1 [==============================] - 1s 799ms/step
# 1/1 [==============================] - 1s 748ms/step
# 1/1 [==============================] - 1s 887ms/step
# 1/1 [==============================] - 1s 784ms/step
# 1/1 [==============================] - 1s 742ms/step
# 1/1 [==============================] - 1s 735ms/step

# %% [markdown]
# ## YOLO v5

# %% [markdown]
# 하나의 이미지를 3x3 그리드로 자르고, 각 그리드에 대해 Bounding Box가 포함되어 있는지 확인하려면, 먼저 이미지의 전체 크기를 알아야 합니다. 이미지의 크기를 알면 각 그리드의 좌표 범위를 계산할 수 있습니다. 그런 다음, 각 Bounding Box의 좌표가 어떤 그리드에 속하는지 확인합니다.

# %% [markdown]
# ### 3x3 : Big Image

# %%
import json
# JSON 파일 경로
json_data_path = r"C:\Users\USER\bomishot\Solving_ReCAPTCHA_v2_Challenge_with_ViT\yolov5\detected_results.json"

# JSON 파일 로드
with open(json_data_path, 'r', encoding='utf-8') as f:
    json_data = json.load(f)

# %%
json_data
# Out:
# {'Hydrant (100)': [{'label': 'fire hydrant',
#    'confidence': '0.87',
#    'bounding_box': [47.0, 38.0, 76.0, 99.0]}],
#  'Hydrant (101)': [{'label': 'fire hydrant',
#    'confidence': '0.78',
#    'bounding_box': [51.0, 17.0, 102.0, 119.0]}],
#  'Hydrant (102)': [],
#  'Hydrant (103)': [{'label': 'fire hydrant',
#    'confidence': '0.88',
#    'bounding_box': [43.0, 20.0, 87.0, 91.0]}],
#  'Hydrant (104)': [{'label': 'fire hydrant',
#    'confidence': '0.82',
#    'bounding_box': [51.0, 34.0, 92.0, 99.0]}],
#  'Hydrant (105)': [{'label': 'person',
#    'confidence': '0.73',
#    'bounding_box': [33.0, 54.0, 111.0, 120.0]}],
#  'Hydrant (106)': [{'label': 'fire hydrant',
#    'confidence': '0.83',
#    'bounding_box': [47.0, 29.0, 86.0, 119.0]}],
#  'Hydrant (107)': [{'label': 'fire hydrant',
#    'confidence': '0.46',
#    'bounding_box': [23.0, 42.0, 63.0, 116.0]}],
#  'Hydrant (108)': [{'label': 'fire hydrant',
#    'confidence': '0.53',
#    'bounding_box': [52.0, 30.0, 82.0, 91.0]}],
#  'Hydrant (109)': [],
#  'Hydrant (110)': [],
#  'Hydrant (111)': [{'label': 'fire hydrant',
#    'confidence': '0.86',
#    'bounding_box': [30.0, 47.0, 71.0, 103.0]}],
#  'Hydrant (112)': [{'label': 'fire hydrant',
#    'confidence': '0.84',
#    'bounding_box': [39.0, 22.0, 85.0, 101.0]}],
#  'Hydrant (113)': [{'label': 'fire hydrant',
#    'confidence': '0.79',
#    'bounding_box': [72.0, 19.0, 109.0, 111.0]}],
#  'Hydrant (114)': [{'label': 'fire hydrant',
#    'confidence': '0.81',
#    'bounding_box': [6.0, 28.0, 41.0, 108.0]}],
#  'Hydrant (115)': [{'label': 'fire hydrant',
#    'confidence': '0.80',
#    'bounding_box': [49.0, 54.0, 88.0, 119.0]}],
#  'Hydrant (116)': [],
#  'Hydrant (117)': [{'label': 'fire hydrant',
#    'confidence': '0.72',
#    'bounding_box': [52.0, 12.0, 97.0, 93.0]}],
#  'Hydrant (118)': [{'label': 'sheep',
#    'confidence': '0.42',
#    'bounding_box': [38.0, 58.0, 69.0, 119.0]}],
#  'Hydrant (119)': [{'label': 'fire hydrant',
#    'confidence': '0.79',
#    'bounding_box': [30.0, 58.0, 65.0, 120.0]}],
#  'Hydrant (120)': [{'label': 'fire hydrant',
#    'confidence': '0.88',
#    'bounding_box': [39.0, 58.0, 79.0, 120.0]}],
#  'Hydrant (121)': [{'label': 'fire hydrant',
#    'confidence': '0.88',
#    'bounding_box': [43.0, 50.0, 81.0, 112.0]}],
#  'Hydrant (122)': [{'label': 'fire hydrant',
#    'confidence': '0.51',
#    'bounding_box': [42.0, 3.0, 103.0, 119.0]}],
#  'Hydrant (123)': [{'label': 'person',
#    'confidence': '0.79',
#    'bounding_box': [13.0, 15.0, 53.0, 91.0]}],
#  'Hydrant (124)': [{'label': 'fire hydrant',
#    'confidence': '0.91',
#    'bounding_box': [28.0, 21.0, 76.0, 120.0]}],
#  'Hydrant (125)': [{'label': 'fire hydrant',
#    'confidence': '0.60',
#    'bounding_box': [38.0, 47.0, 75.0, 120.0]}],
#  'Hydrant (126)': [{'label': 'fire hydrant',
#    'confidence': '0.85',
#    'bounding_box': [47.0, 40.0, 87.0, 120.0]}],
#  'Hydrant (127)': [{'label': 'fire hydrant',
#    'confidence': '0.91',
#    'bounding_box': [44.0, 32.0, 86.0, 120.0]}],
#  'Hydrant (128)': [{'label': 'fire hydrant',
#    'confidence': '0.85',
#    'bounding_box': [44.0, 19.0, 72.0, 78.0]}],
#  'Hydrant (129)': [{'label': 'teddy bear',
#    'confidence': '0.42',
#    'bounding_box': [1.0, 2.0, 55.0, 100.0]}],
#  'Hydrant (130)': [],
#  'Hydrant (131)': [{'label': 'fire hydrant',
#    'confidence': '0.84',
#    'bounding_box': [34.0, 19.0, 71.0, 97.0]}],
#  'Hydrant (132)': [],
#  'Hydrant (133)': [{'label': 'fire hydrant',
#    'confidence': '0.75',
#    'bounding_box': [24.0, 11.0, 82.0, 115.0]}],
#  'Hydrant (134)': [{'label': 'fire hydrant',
#    'confidence': '0.88',
#    'bounding_box': [55.0, 35.0, 92.0, 113.0]}],
#  'Hydrant (135)': [{'label': 'fire hydrant',
#    'confidence': '0.44',
#    'bounding_box': [31.0, 1.0, 78.0, 118.0]}],
#  'Hydrant (136)': [],
#  'Hydrant (137)': [{'label': 'fire hydrant',
#    'confidence': '0.82',
#    'bounding_box': [63.0, 36.0, 88.0, 106.0]}],
#  'Hydrant (138)': [],
#  'Hydrant (139)': [{'label': 'fire hydrant',
#    'confidence': '0.38',
#    'bounding_box': [2.0, 21.0, 73.0, 119.0]}],
#  'Hydrant (140)': [{'label': 'fire hydrant',
#    'confidence': '0.29',
#    'bounding_box': [36.0, 0.0, 79.0, 59.0]}],
#  'Hydrant (141)': [{'label': 'fire hydrant',
#    'confidence': '0.85',
#    'bounding_box': [40.0, 46.0, 81.0, 120.0]}],
#  'Hydrant (142)': [{'label': 'fire hydrant',
#    'confidence': '0.75',
#    'bounding_box': [53.0, 29.0, 81.0, 106.0]}],
#  'Hydrant (143)': [{'label': 'fire hydrant',
#    'confidence': '0.78',
#    'bounding_box': [30.0, 40.0, 70.0, 119.0]}],
#  'Hydrant (144)': [{'label': 'fire hydrant',
#    'confidence': '0.64',
#    'bounding_box': [28.0, 11.0, 78.0, 105.0]}],
#  'Hydrant (145)': [],
#  'Hydrant (146)': [{'label': 'fire hydrant',
#    'confidence': '0.83',
#    'bounding_box': [57.0, 29.0, 84.0, 93.0]}],
#  'Hydrant (147)': [{'label': 'fire hydrant',
#    'confidence': '0.82',
#    'bounding_box': [42.0, 0.0, 76.0, 50.0]}],
#  'Hydrant (148)': [{'label': 'fire hydrant',
#    'confidence': '0.84',
#    'bounding_box': [30.0, 31.0, 83.0, 97.0]}],
#  'Hydrant (149)': [{'label': 'fire hydrant',
#    'confidence': '0.35',
#    'bounding_box': [49.0, 3.0, 85.0, 80.0]}],
#  'Hydrant (150)': [{'label': 'person',
#    'confidence': '0.50',
#    'bounding_box': [101.0, 0.0, 120.0, 55.0]},
#   {'label': 'fire hydrant',
#    'confidence': '0.72',
#    'bounding_box': [0.0, 28.0, 35.0, 113.0]}],
#  'Hydrant (151)': [{'label': 'fire hydrant',
#    'confidence': '0.32',
#    'bounding_box': [37.0, 7.0, 86.0, 118.0]}],
#  'Hydrant (152)': [{'label': 'fire hydrant',
#    'confidence': '0.57',
#    'bounding_box': [34.0, 7.0, 78.0, 84.0]}],
#  'Hydrant (153)': [{'label': 'fire hydrant',
#    'confidence': '0.88',
#    'bounding_box': [90.0, 41.0, 119.0, 100.0]}],
#  'Hydrant (154)': [{'label': 'fire hydrant',
#    'confidence': '0.90',
#    'bounding_box': [52.0, 27.0, 76.0, 76.0]}],
#  'Hydrant (155)': [{'label': 'fire hydrant',
#    'confidence': '0.79',
#    'bounding_box': [33.0, 34.0, 85.0, 120.0]}],
#  'Hydrant (156)': [{'label': 'fire hydrant',
#    'confidence': '0.85',
#    'bounding_box': [33.0, 11.0, 93.0, 118.0]}],
#  'Hydrant (157)': [],
#  'Hydrant (158)': [{'label': 'fire hydrant',
#    'confidence': '0.67',
#    'bounding_box': [61.0, 48.0, 91.0, 120.0]}],
#  'Hydrant (159)': [],
#  'Hydrant (160)': [{'label': 'fire hydrant',
#    'confidence': '0.86',
#    'bounding_box': [45.0, 14.0, 80.0, 91.0]}],
#  'Hydrant (161)': [{'label': 'person',
#    'confidence': '0.28',
#    'bounding_box': [37.0, 22.0, 70.0, 101.0]}],
#  'Hydrant (162)': [{'label': 'fire hydrant',
#    'confidence': '0.79',
#    'bounding_box': [37.0, 27.0, 72.0, 104.0]}],
#  'Hydrant (163)': [{'label': 'fire hydrant',
#    'confidence': '0.42',
#    'bounding_box': [43.0, 46.0, 73.0, 117.0]}],
#  'Hydrant (164)': [{'label': 'fire hydrant',
#    'confidence': '0.88',
#    'bounding_box': [46.0, 58.0, 74.0, 120.0]}],
#  'Hydrant (165)': [{'label': 'fire hydrant',
#    'confidence': '0.89',
#    'bounding_box': [68.0, 52.0, 93.0, 109.0]}],
#  'Hydrant (166)': [{'label': 'fire hydrant',
#    'confidence': '0.52',
#    'bounding_box': [52.0, 4.0, 103.0, 108.0]}],
#  'Hydrant (167)': [{'label': 'fire hydrant',
#    'confidence': '0.81',
#    'bounding_box': [39.0, 26.0, 90.0, 120.0]}],
#  'Hydrant (168)': [{'label': 'fire hydrant',
#    'confidence': '0.80',
#    'bounding_box': [38.0, 31.0, 71.0, 88.0]}],
#  'Hydrant (169)': [],
#  'Hydrant (170)': [{'label': 'fire hydrant',
#    'confidence': '0.83',
#    'bounding_box': [50.0, 57.0, 83.0, 120.0]}],
#  'Hydrant (171)': [{'label': 'fire hydrant',
#    'confidence': '0.89',
#    'bounding_box': [65.0, 35.0, 98.0, 120.0]}],
#  'Hydrant (172)': [{'label': 'fire hydrant',
#    'confidence': '0.89',
#    'bounding_box': [61.0, 34.0, 92.0, 113.0]}],
#  'Hydrant (173)': [{'label': 'fire hydrant',
#    'confidence': '0.68',
#    'bounding_box': [40.0, 33.0, 72.0, 94.0]}],
#  'Hydrant (174)': [{'label': 'fire hydrant',
#    'confidence': '0.90',
#    'bounding_box': [27.0, 40.0, 72.0, 106.0]}],
#  'Hydrant (175)': [{'label': 'fire hydrant',
#    'confidence': '0.72',
#    'bounding_box': [16.0, 2.0, 86.0, 89.0]}],
#  'Hydrant (176)': [{'label': 'dog',
#    'confidence': '0.28',
#    'bounding_box': [86.0, 25.0, 120.0, 104.0]},
#   {'label': 'fire hydrant',
#    'confidence': '0.60',
#    'bounding_box': [86.0, 24.0, 120.0, 105.0]}],
#  'Hydrant (177)': [{'label': 'fire hydrant',
#    'confidence': '0.90',
#    'bounding_box': [49.0, 47.0, 90.0, 120.0]}],
#  'Hydrant (178)': [{'label': 'fire hydrant',
#    'confidence': '0.83',
#    'bounding_box': [51.0, 23.0, 83.0, 105.0]}],
#  'Hydrant (179)': [{'label': 'fire hydrant',
#    'confidence': '0.88',
#    'bounding_box': [56.0, 25.0, 91.0, 106.0]}],
#  'Hydrant (180)': [{'label': 'fire hydrant',
#    'confidence': '0.88',
#    'bounding_box': [44.0, 9.0, 71.0, 61.0]}],
#  'Hydrant (181)': [{'label': 'person',
#    'confidence': '0.35',
#    'bounding_box': [23.0, 2.0, 94.0, 97.0]}]}

# %%
hydrant_100_img_path = r"C:\Users\USER\bomishot\Solving_ReCAPTCHA_v2_Challenge_with_ViT\Data\Big Image Data\Hydrant\Hydrant (100).png"

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import numpy as np

# 이미지 경로 지정
img_path = r"C:\Users\USER\bomishot\Solving_ReCAPTCHA_v2_Challenge_with_ViT\Data\Big Image Data\Hydrant\Hydrant (100).png"

# 이미지 불러오기
img = plt.imread(img_path)

# 캔버스 생성
fig, ax = plt.subplots()

# 원본 이미지 표시
ax.imshow(img)

# 이미지의 크기 (가로, 세로)
img_width = img.shape[1]  # 이미지의 가로 크기
img_height = img.shape[0]  # 이미지의 세로 크기

# 그리드의 크기 계산
grid_width = img_width // 4
grid_height = img_height // 4

# 각 그리드를 이미지 위에 표시
for i in range(4):
    for j in range(4):
        # 그리드의 경계 좌표 계산
        x = j * grid_width
        y = i * grid_height

        # 그리드 그리기
        rect = patches.Rectangle((x, y), grid_width, grid_height, linewidth=1, edgecolor='white', facecolor='none')
        ax.add_patch(rect)

# 이미지 보여주기
plt.show()

# %%
# 이미지의 크기 (가로, 세로)
img_width = 120
img_height = 120

# 그리드의 크기 계산
grid_width = img_width // 3
grid_height = img_height // 3

result_dict = {}

for key, detections in json_data.items():
    detected_grids = [[False, False, False] for _ in range(3)]
    for detection in detections:
        if detection["label"] == "fire hydrant":
            # Bounding Box의 4개의 좌표 계산
            x_min = detection["bounding_box"][0]
            y_min = detection["bounding_box"][1]
            x_max = detection["bounding_box"][2]
            y_max = detection["bounding_box"][3]

            # Bounding Box가 속한 그리드를 찾기
            for i in range(3):
                for j in range(3):
                    # 현재 grid의 최소 최대 x,y 좌표 계산
                    grid_x_min = i * grid_width
                    grid_y_min = j * grid_height
                    grid_x_max = (i + 1) * grid_width
                    grid_y_max = (j + 1) * grid_height

                    # 그리드와 Bounding Box가 겹치는 경우
                    # Bounding Box의 x좌표 범위와 그리드의 x좌표 범위가 겹치고,
                    # Bounding Box의 y좌표 범위와 그리드의 y좌표 범위가 겹칠 때,
                    # 해당 그리드는 Bounding Box에 겹치는 것
                    if (x_min < grid_x_max and x_max > grid_x_min and
                            y_min < grid_y_max and y_max > grid_y_min):
                        detected_grids[j][i] = True

    # 결과 딕셔너리에 key별 detected_grids 저장
    result_dict[key] = detected_grids

# 최종 결과 출력
for key, grids in result_dict.items():
    print(f"For key: {key}")
    for row in grids:
        print(row)
    print()
# Out:
# For key: Hydrant (100)
# [False, True, False]
# [False, True, False]
# [False, True, False]
#
# For key: Hydrant (101)
# [False, True, True]
# [False, True, True]
# [False, True, True]
#
# For key: Hydrant (102)
# [False, False, False]
# [False, False, False]
# [False, False, False]
#
# For key: Hydrant (103)
# [False, True, True]
# [False, True, True]
# [False, True, True]
#
# For key: Hydrant (104)
# [False, True, True]
# [False, True, True]
# [False, True, True]
#
# For key: Hydrant (105)
# [False, False, False]
# [False, False, False]
# [False, False, False]
#
# For key: Hydrant (106)
# [False, True, True]
# [False, True, True]
# [False, True, True]
#
# For key: Hydrant (107)
# [False, False, False]
# [True, True, False]
# [True, True, False]
#
# For key: Hydrant (108)
# [False, True, True]
# [False, True, True]
# [False, True, True]
#
# For key: Hydrant (109)
# [False, False, False]
# [False, False, False]
# [False, False, False]
#
# For key: Hydrant (110)
# [False, False, False]
# [False, False, False]
# [False, False, False]
#
# For key: Hydrant (111)
# [False, False, False]
# [True, True, False]
# [True, True, False]
#
# For key: Hydrant (112)
# [True, True, True]
# [True, True, True]
# [True, True, True]
#
# For key: Hydrant (113)
# [False, True, True]
# [False, True, True]
# [False, True, True]
#
# For key: Hydrant (114)
# [True, True, False]
# [True, True, False]
# [True, True, False]
#
# For key: Hydrant (115)
# [False, False, False]
# [False, True, True]
# [False, True, True]
#
# For key: Hydrant (116)
# [False, False, False]
# [False, False, False]
# [False, False, False]
#
# For key: Hydrant (117)
# [False, True, True]
# [False, True, True]
# [False, True, True]
#
# For key: Hydrant (118)
# [False, False, False]
# [False, False, False]
# [False, False, False]
#
# For key: Hydrant (119)
# [False, False, False]
# [True, True, False]
# [True, True, False]
#
# For key: Hydrant (120)
# [False, False, False]
# [True, True, False]
# [True, True, False]
#
# For key: Hydrant (121)
# [False, False, False]
# [False, True, True]
# [False, True, True]
#
# For key: Hydrant (122)
# [False, True, True]
# [False, True, True]
# [False, True, True]
#
# For key: Hydrant (123)
# [False, False, False]
# [False, False, False]
# [False, False, False]
#
# For key: Hydrant (124)
# [True, True, False]
# [True, True, False]
# [True, True, False]
#
# For key: Hydrant (125)
# [False, False, False]
# [True, True, False]
# [True, True, False]
#
# For key: Hydrant (126)
# [False, False, False]
# [False, True, True]
# [False, True, True]
#
# For key: Hydrant (127)
# [False, True, True]
# [False, True, True]
# [False, True, True]
#
# For key: Hydrant (128)
# [False, True, False]
# [False, True, False]
# [False, False, False]
#
# For key: Hydrant (129)
# [False, False, False]
# [False, False, False]
# [False, False, False]
#
# For key: Hydrant (130)
# [False, False, False]
# [False, False, False]
# [False, False, False]
#
# For key: Hydrant (131)
# [True, True, False]
# [True, True, False]
# [True, True, False]
#
# For key: Hydrant (132)
# [False, False, False]
# [False, False, False]
# [False, False, False]
#
# For key: Hydrant (133)
# [True, True, True]
# [True, True, True]
# [True, True, True]
#
# For key: Hydrant (134)
# [False, True, True]
# [False, True, True]
# [False, True, True]
#
# For key: Hydrant (135)
# [True, True, False]
# [True, True, False]
# [True, True, False]
#
# For key: Hydrant (136)
# [False, False, False]
# [False, False, False]
# [False, False, False]
#
# For key: Hydrant (137)
# [False, True, True]
# [False, True, True]
# [False, True, True]
#
# For key: Hydrant (138)
# [False, False, False]
# [False, False, False]
# [False, False, False]
#
# For key: Hydrant (139)
# [True, True, False]
# [True, True, False]
# [True, True, False]
#
# For key: Hydrant (140)
# [True, True, False]
# [True, True, False]
# [False, False, False]
#
# For key: Hydrant (141)
# [False, False, False]
# [False, True, True]
# [False, True, True]
#
# For key: Hydrant (142)
# [False, True, True]
# [False, True, True]
# [False, True, True]
#
# For key: Hydrant (143)
# [False, False, False]
# [True, True, False]
# [True, True, False]
#
# For key: Hydrant (144)
# [True, True, False]
# [True, True, False]
# [True, True, False]
#
# For key: Hydrant (145)
# [False, False, False]
# [False, False, False]
# [False, False, False]
#
# For key: Hydrant (146)
# [False, True, True]
# [False, True, True]
# [False, True, True]
#
# For key: Hydrant (147)
# [False, True, False]
# [False, True, False]
# [False, False, False]
#
# For key: Hydrant (148)
# [True, True, True]
# [True, True, True]
# [True, True, True]
#
# For key: Hydrant (149)
# [False, True, True]
# [False, True, True]
# [False, False, False]
#
# For key: Hydrant (150)
# [True, False, False]
# [True, False, False]
# [True, False, False]
#
# For key: Hydrant (151)
# [True, True, True]
# [True, True, True]
# [True, True, True]
#
# For key: Hydrant (152)
# [True, True, False]
# [True, True, False]
# [True, True, False]
#
# For key: Hydrant (153)
# [False, False, False]
# [False, False, True]
# [False, False, True]
#
# For key: Hydrant (154)
# [False, True, False]
# [False, True, False]
# [False, False, False]
#
# For key: Hydrant (155)
# [True, True, True]
# [True, True, True]
# [True, True, True]
#
# For key: Hydrant (156)
# [True, True, True]
# [True, True, True]
# [True, True, True]
#
# For key: Hydrant (157)
# [False, False, False]
# [False, False, False]
# [False, False, False]
#
# For key: Hydrant (158)
# [False, False, False]
# [False, True, True]
# [False, True, True]
#
# For key: Hydrant (159)
# [False, False, False]
# [False, False, False]
# [False, False, False]
#
# For key: Hydrant (160)
# [False, True, False]
# [False, True, False]
# [False, True, False]
#
# For key: Hydrant (161)
# [False, False, False]
# [False, False, False]
# [False, False, False]
#
# For key: Hydrant (162)
# [True, True, False]
# [True, True, False]
# [True, True, False]
#
# For key: Hydrant (163)
# [False, False, False]
# [False, True, False]
# [False, True, False]
#
# For key: Hydrant (164)
# [False, False, False]
# [False, True, False]
# [False, True, False]
#
# For key: Hydrant (165)
# [False, False, False]
# [False, True, True]
# [False, True, True]
#
# For key: Hydrant (166)
# [False, True, True]
# [False, True, True]
# [False, True, True]
#
# For key: Hydrant (167)
# [True, True, True]
# [True, True, True]
# [True, True, True]
#
# For key: Hydrant (168)
# [True, True, False]
# [True, True, False]
# [True, True, False]
#
# For key: Hydrant (169)
# [False, False, False]
# [False, False, False]
# [False, False, False]
#
# For key: Hydrant (170)
# [False, False, False]
# [False, True, True]
# [False, True, True]
#
# For key: Hydrant (171)
# [False, True, True]
# [False, True, True]
# [False, True, True]
#
# For key: Hydrant (172)
# [False, True, True]
# [False, True, True]
# [False, True, True]
#
# For key: Hydrant (173)
# [False, True, False]
# [False, True, False]
# [False, True, False]
#
# For key: Hydrant (174)
# [False, False, False]
# [True, True, False]
# [True, True, False]
#
# For key: Hydrant (175)
# [True, True, True]
# [True, True, True]
# [True, True, True]
#
# For key: Hydrant (176)
# [False, False, True]
# [False, False, True]
# [False, False, True]
#
# For key: Hydrant (177)
# [False, False, False]
# [False, True, True]
# [False, True, True]
#
# For key: Hydrant (178)
# [False, True, True]
# [False, True, True]
# [False, True, True]
#
# For key: Hydrant (179)
# [False, True, True]
# [False, True, True]
# [False, True, True]
#
# For key: Hydrant (180)
# [False, True, False]
# [False, True, False]
# [False, False, False]
#
# For key: Hydrant (181)
# [False, False, False]
# [False, False, False]
# [False, False, False]

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import numpy as np

# key별로 이미지 경로 설정
img_paths = {
    'Hydrant (100)': r"C:\Users\USER\bomishot\Solving_ReCAPTCHA_v2_Challenge_with_ViT\yolov5\runs\detect\exp7\Hydrant (100).png",
    # 다른 key에 대한 이미지 경로도 추가...
}

# 각 key에 대해 이미지 처리
for key, detected_grids in result_dict.items():
    # 해당 key의 이미지 경로 찾기
    try:
        img_path = img_paths[key]
    except KeyError:
        continue
    # 이미지 불러오기
    img = plt.imread(img_path)

    # 캔버스 생성
    fig, ax = plt.subplots()

    # 원본 이미지 표시
    ax.imshow(img)
    # 각 그리드의 탐지 결과를 이미지 위에 표시
    for i in range(3):
        for j in range(3):
            # 그리드의 경계 좌표 계산
            x = j * grid_width
            y = i * grid_height
            # 탐지된 경우, 그리드를 빨간색으로 표시
            if detected_grids[i][j]:
                color = 'red'
                # 빨간색 동그라미 그리기 (여기서 (x + grid_width / 2, y + grid_height / 2)는 그리드의 중심점)
                circle = patches.Circle((x + grid_width / 2, y + grid_height / 2), radius=10, color=color)
                ax.add_patch(circle)
            else:
                color = 'none'

            # 그리드 그리기
            rect = patches.Rectangle((x, y), grid_width, grid_height, linewidth=1, edgecolor='white', facecolor='none')
            ax.add_patch(rect)

    # 이미지 제목 설정
    plt.title(key)

    # 이미지 보여주기
    plt.show()

# %% [markdown]
# ### 4x4 image

# %%
# 이미지의 크기 (가로, 세로)
img_width = 120
img_height = 120

# 그리드의 크기 계산
grid_width = img_width // 4
grid_height = img_height // 4

result_dict = {}

for key, detections in json_data.items():
    detected_grids = [[False, False, False, False] for _ in range(4)]
    for detection in detections:
        if detection["label"] == "fire hydrant":
            # Bounding Box의 4개의 좌표 계산
            x_min = detection["bounding_box"][0]
            y_min = detection["bounding_box"][1]
            x_max = detection["bounding_box"][2]
            y_max = detection["bounding_box"][3]

            # Bounding Box가 속한 그리드를 찾기
            for i in range(4):
                for j in range(4):
                    # 현재 grid의 최소 최대 x,y 좌표 계산
                    grid_x_min = i * grid_width
                    grid_y_min = j * grid_height
                    grid_x_max = (i + 1) * grid_width
                    grid_y_max = (j + 1) * grid_height

                    # 그리드와 Bounding Box가 겹치는 경우
                    # Bounding Box의 x좌표 범위와 그리드의 x좌표 범위가 겹치고,
                    # Bounding Box의 y좌표 범위와 그리드의 y좌표 범위가 겹칠 때,
                    # 해당 그리드는 Bounding Box에 겹치는 것
                    if (x_min < grid_x_max and x_max > grid_x_min and
                            y_min < grid_y_max and y_max > grid_y_min):
                        detected_grids[j][i] = True

    # 결과 딕셔너리에 key별 detected_grids 저장
    result_dict[key] = detected_grids

# 최종 결과 출력
for key, grids in result_dict.items():
    print(f"For key: {key}")
    for row in grids:
        print(row)
    print()
# Out:
# For key: Hydrant (100)
# [False, False, False, False]
# [False, True, True, False]
# [False, True, True, False]
# [False, True, True, False]
#
# For key: Hydrant (101)
# [False, True, True, True]
# [False, True, True, True]
# [False, True, True, True]
# [False, True, True, True]
#
# For key: Hydrant (102)
# [False, False, False, False]
# [False, False, False, False]
# [False, False, False, False]
# [False, False, False, False]
#
# For key: Hydrant (103)
# [False, True, True, False]
# [False, True, True, False]
# [False, True, True, False]
# [False, True, True, False]
#
# For key: Hydrant (104)
# [False, False, False, False]
# [False, True, True, True]
# [False, True, True, True]
# [False, True, True, True]
#
# For key: Hydrant (105)
# [False, False, False, False]
# [False, False, False, False]
# [False, False, False, False]
# [False, False, False, False]
#
# For key: Hydrant (106)
# [False, True, True, False]
# [False, True, True, False]
# [False, True, True, False]
# [False, True, True, False]
#
# For key: Hydrant (107)
# [False, False, False, False]
# [True, True, True, False]
# [True, True, True, False]
# [True, True, True, False]
#
# For key: Hydrant (108)
# [False, False, False, False]
# [False, True, True, False]
# [False, True, True, False]
# [False, True, True, False]
#
# For key: Hydrant (109)
# [False, False, False, False]
# [False, False, False, False]
# [False, False, False, False]
# [False, False, False, False]
#
# For key: Hydrant (110)
# [False, False, False, False]
# [False, False, False, False]
# [False, False, False, False]
# [False, False, False, False]
#
# For key: Hydrant (111)
# [False, False, False, False]
# [False, True, True, False]
# [False, True, True, False]
# [False, True, True, False]
#
# For key: Hydrant (112)
# [False, True, True, False]
# [False, True, True, False]
# [False, True, True, False]
# [False, True, True, False]
#
# For key: Hydrant (113)
# [False, False, True, True]
# [False, False, True, True]
# [False, False, True, True]
# [False, False, True, True]
#
# For key: Hydrant (114)
# [True, True, False, False]
# [True, True, False, False]
# [True, True, False, False]
# [True, True, False, False]
#
# For key: Hydrant (115)
# [False, False, False, False]
# [False, True, True, False]
# [False, True, True, False]
# [False, True, True, False]
#
# For key: Hydrant (116)
# [False, False, False, False]
# [False, False, False, False]
# [False, False, False, False]
# [False, False, False, False]
#
# For key: Hydrant (117)
# [False, True, True, True]
# [False, True, True, True]
# [False, True, True, True]
# [False, True, True, True]
#
# For key: Hydrant (118)
# [False, False, False, False]
# [False, False, False, False]
# [False, False, False, False]
# [False, False, False, False]
#
# For key: Hydrant (119)
# [False, False, False, False]
# [False, True, True, False]
# [False, True, True, False]
# [False, True, True, False]
#
# For key: Hydrant (120)
# [False, False, False, False]
# [False, True, True, False]
# [False, True, True, False]
# [False, True, True, False]
#
# For key: Hydrant (121)
# [False, False, False, False]
# [False, True, True, False]
# [False, True, True, False]
# [False, True, True, False]
#
# For key: Hydrant (122)
# [False, True, True, True]
# [False, True, True, True]
# [False, True, True, True]
# [False, True, True, True]
#
# For key: Hydrant (123)
# [False, False, False, False]
# [False, False, False, False]
# [False, False, False, False]
# [False, False, False, False]
#
# For key: Hydrant (124)
# [True, True, True, False]
# [True, True, True, False]
# [True, True, True, False]
# [True, True, True, False]
#
# For key: Hydrant (125)
# [False, False, False, False]
# [False, True, True, False]
# [False, True, True, False]
# [False, True, True, False]
#
# For key: Hydrant (126)
# [False, False, False, False]
# [False, True, True, False]
# [False, True, True, False]
# [False, True, True, False]
#
# For key: Hydrant (127)
# [False, False, False, False]
# [False, True, True, False]
# [False, True, True, False]
# [False, True, True, False]
#
# For key: Hydrant (128)
# [False, True, True, False]
# [False, True, True, False]
# [False, True, True, False]
# [False, False, False, False]
#
# For key: Hydrant (129)
# [False, False, False, False]
# [False, False, False, False]
# [False, False, False, False]
# [False, False, False, False]
#
# For key: Hydrant (130)
# [False, False, False, False]
# [False, False, False, False]
# [False, False, False, False]
# [False, False, False, False]
#
# For key: Hydrant (131)
# [False, True, True, False]
# [False, True, True, False]
# [False, True, True, False]
# [False, True, True, False]
#
# For key: Hydrant (132)
# [False, False, False, False]
# [False, False, False, False]
# [False, False, False, False]
# [False, False, False, False]
#
# For key: Hydrant (133)
# [True, True, True, False]
# [True, True, True, False]
# [True, True, True, False]
# [True, True, True, False]
#
# For key: Hydrant (134)
# [False, False, False, False]
# [False, True, True, True]
# [False, True, True, True]
# [False, True, True, True]
#
# For key: Hydrant (135)
# [False, True, True, False]
# [False, True, True, False]
# [False, True, True, False]
# [False, True, True, False]
#
# For key: Hydrant (136)
# [False, False, False, False]
# [False, False, False, False]
# [False, False, False, False]
# [False, False, False, False]
#
# For key: Hydrant (137)
# [False, False, False, False]
# [False, False, True, False]
# [False, False, True, False]
# [False, False, True, False]
#
# For key: Hydrant (138)
# [False, False, False, False]
# [False, False, False, False]
# [False, False, False, False]
# [False, False, False, False]
#
# For key: Hydrant (139)
# [True, True, True, False]
# [True, True, True, False]
# [True, True, True, False]
# [True, True, True, False]
#
# For key: Hydrant (140)
# [False, True, True, False]
# [False, True, True, False]
# [False, False, False, False]
# [False, False, False, False]
#
# For key: Hydrant (141)
# [False, False, False, False]
# [False, True, True, False]
# [False, True, True, False]
# [False, True, True, False]
#
# For key: Hydrant (142)
# [False, True, True, False]
# [False, True, True, False]
# [False, True, True, False]
# [False, True, True, False]
#
# For key: Hydrant (143)
# [False, False, False, False]
# [False, True, True, False]
# [False, True, True, False]
# [False, True, True, False]
#
# For key: Hydrant (144)
# [True, True, True, False]
# [True, True, True, False]
# [True, True, True, False]
# [True, True, True, False]
#
# For key: Hydrant (145)
# [False, False, False, False]
# [False, False, False, False]
# [False, False, False, False]
# [False, False, False, False]
#
# For key: Hydrant (146)
# [False, True, True, False]
# [False, True, True, False]
# [False, True, True, False]
# [False, True, True, False]
#
# For key: Hydrant (147)
# [False, True, True, False]
# [False, True, True, False]
# [False, False, False, False]
# [False, False, False, False]
#
# For key: Hydrant (148)
# [False, False, False, False]
# [False, True, True, False]
# [False, True, True, False]
# [False, True, True, False]
#
# For key: Hydrant (149)
# [False, True, True, False]
# [False, True, True, False]
# [False, True, True, False]
# [False, False, False, False]
#
# For key: Hydrant (150)
# [True, True, False, False]
# [True, True, False, False]
# [True, True, False, False]
# [True, True, False, False]
#
# For key: Hydrant (151)
# [False, True, True, False]
# [False, True, True, False]
# [False, True, True, False]
# [False, True, True, False]
#
# For key: Hydrant (152)
# [False, True, True, False]
# [False, True, True, False]
# [False, True, True, False]
# [False, False, False, False]
#
# For key: Hydrant (153)
# [False, False, False, False]
# [False, False, False, True]
# [False, False, False, True]
# [False, False, False, True]
#
# For key: Hydrant (154)
# [False, True, True, False]
# [False, True, True, False]
# [False, True, True, False]
# [False, False, False, False]
#
# For key: Hydrant (155)
# [False, False, False, False]
# [False, True, True, False]
# [False, True, True, False]
# [False, True, True, False]
#
# For key: Hydrant (156)
# [False, True, True, True]
# [False, True, True, True]
# [False, True, True, True]
# [False, True, True, True]
#
# For key: Hydrant (157)
# [False, False, False, False]
# [False, False, False, False]
# [False, False, False, False]
# [False, False, False, False]
#
# For key: Hydrant (158)
# [False, False, False, False]
# [False, False, True, True]
# [False, False, True, True]
# [False, False, True, True]
#
# For key: Hydrant (159)
# [False, False, False, False]
# [False, False, False, False]
# [False, False, False, False]
# [False, False, False, False]
#
# For key: Hydrant (160)
# [False, True, True, False]
# [False, True, True, False]
# [False, True, True, False]
# [False, True, True, False]
#
# For key: Hydrant (161)
# [False, False, False, False]
# [False, False, False, False]
# [False, False, False, False]
# [False, False, False, False]
#
# For key: Hydrant (162)
# [False, True, True, False]
# [False, True, True, False]
# [False, True, True, False]
# [False, True, True, False]
#
# For key: Hydrant (163)
# [False, False, False, False]
# [False, True, True, False]
# [False, True, True, False]
# [False, True, True, False]
#
# For key: Hydrant (164)
# [False, False, False, False]
# [False, True, True, False]
# [False, True, True, False]
# [False, True, True, False]
#
# For key: Hydrant (165)
# [False, False, False, False]
# [False, False, True, True]
# [False, False, True, True]
# [False, False, True, True]
#
# For key: Hydrant (166)
# [False, True, True, True]
# [False, True, True, True]
# [False, True, True, True]
# [False, True, True, True]
#
# For key: Hydrant (167)
# [False, True, True, False]
# [False, True, True, False]
# [False, True, True, False]
# [False, True, True, False]
#
# For key: Hydrant (168)
# [False, False, False, False]
# [False, True, True, False]
# [False, True, True, False]
# [False, False, False, False]
#
# For key: Hydrant (169)
# [False, False, False, False]
# [False, False, False, False]
# [False, False, False, False]
# [False, False, False, False]
#
# For key: Hydrant (170)
# [False, False, False, False]
# [False, True, True, False]
# [False, True, True, False]
# [False, True, True, False]
#
# For key: Hydrant (171)
# [False, False, False, False]
# [False, False, True, True]
# [False, False, True, True]
# [False, False, True, True]
#
# For key: Hydrant (172)
# [False, False, False, False]
# [False, False, True, True]
# [False, False, True, True]
# [False, False, True, True]
#
# For key: Hydrant (173)
# [False, False, False, False]
# [False, True, True, False]
# [False, True, True, False]
# [False, True, True, False]
#
# For key: Hydrant (174)
# [False, False, False, False]
# [True, True, True, False]
# [True, True, True, False]
# [True, True, True, False]
#
# For key: Hydrant (175)
# [True, True, True, False]
# [True, True, True, False]
# [True, True, True, False]
# [False, False, False, False]
#
# For key: Hydrant (176)
# [False, False, True, True]
# [False, False, True, True]
# [False, False, True, True]
# [False, False, True, True]
#
# For key: Hydrant (177)
# [False, False, False, False]
# [False, True, True, False]
# [False, True, True, False]
# [False, True, True, False]
#
# For key: Hydrant (178)
# [False, True, True, False]
# [False, True, True, False]
# [False, True, True, False]
# [False, True, True, False]
#
# For key: Hydrant (179)
# [False, True, True, True]
# [False, True, True, True]
# [False, True, True, True]
# [False, True, True, True]
#
# For key: Hydrant (180)
# [False, True, True, False]
# [False, True, True, False]
# [False, True, True, False]
# [False, False, False, False]
#
# For key: Hydrant (181)
# [False, False, False, False]
# [False, False, False, False]
# [False, False, False, False]
# [False, False, False, False]

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import numpy as np

# key별로 이미지 경로 설정
img_paths = {
    'Hydrant (100)': r"C:\Users\USER\bomishot\Solving_ReCAPTCHA_v2_Challenge_with_ViT\yolov5\runs\detect\exp7\Hydrant (100).png",
    # 다른 key에 대한 이미지 경로도 추가...
}

# 각 key에 대해 이미지 처리
for key, detected_grids in result_dict.items():
    # 해당 key의 이미지 경로 찾기
    try:
        img_path = img_paths[key]
    except KeyError:
        continue
    # 이미지 불러오기
    img = plt.imread(img_path)

    # 캔버스 생성
    fig, ax = plt.subplots()

    # 원본 이미지 표시
    ax.imshow(img)

    # 각 그리드의 탐지 결과를 이미지 위에 표시
    for i in range(4):
        for j in range(4):
            # 그리드의 경계 좌표 계산
            x = j * grid_width
            y = i * grid_height

            # 탐지된 경우, 그리드를 빨간색으로 표시
            if detected_grids[i][j]:
                color = 'red'
                # 빨간색 동그라미 그리기 (여기서 (x + grid_width / 2, y + grid_height / 2)는 그리드의 중심점)
                circle = patches.Circle((x + grid_width / 2, y + grid_height / 2), radius=10, color=color)
                ax.add_patch(circle)
            else:
                color = 'none'

            # 그리드 그리기
            rect = patches.Rectangle((x, y), grid_width, grid_height, linewidth=1, edgecolor='white', facecolor='none')
            ax.add_patch(rect)

    # 이미지 제목 설정
    plt.title(key)

    # 이미지 보여주기
    plt.show()

# %% [markdown]
# 다른 예시로, car에 대해서도 보이자.
